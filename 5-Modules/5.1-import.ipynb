# %% [markdown]
# ### Import

# %%
import math
math.sqrt(4)
# Out:
# 2.0

# %%
from math import sqrt, pi

print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import numpy as np

print(np.array([1,2,3,4]))
# Out:
# [1 2 3 4]

# %%
from math import *
print(sqrt(64))
# Out:
# 8.0

# %%
from package.maths import *

print(add(2, 4))
print(sub(4,6))
# Out:
# 6
# -2
