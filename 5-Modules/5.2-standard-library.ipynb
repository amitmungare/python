# %%
import array
arr=array.array('i', [1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(4))
print(math.pi)
# Out:
# 2.0
# 3.141592653589793

# %%
import random
print(random.randint(1,5))
print(random.choice(['apple', 'mango', 'orange', 'banana']))
# Out:
# 3
# mango

# %%
import os

print(os.getcwd())
os.mkdir('test_dir')

# %%
import shutil
shutil.copyfile('source.txt', 'destination.txt')
# Out:
# 'destination.txt'

# %%
## data serialization
import json
data={'name':'amit', 'age':26}
json_str=json.dumps(data)
print(json_str)
print(type(json_str))
parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "amit", "age": 26}
# <class 'str'>
# {'name': 'amit', 'age': 26}
# <class 'dict'>

# %%
## csv

import csv
with open('example.csv', mode='w', newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name', 'age'])
    writer.writerow(['amit', 26])

with open('example.csv', mode='r', newline='') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['amit', '26']

# %%
## date time

from datetime import datetime, timedelta

now=datetime.now()
print(now)

yesterday = now - timedelta(days=1)
print(yesterday)
# Out:
# 2026-06-17 22:50:16.109396
# 2026-06-16 22:50:16.109396

# %%
## time

import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1781716867.037706
# 1781716869.043048

# %%
## regular expression

import re

pattern=r'\d+'
text= 'there are 123 apples'
match = re.search(pattern, text)
print(match.group())
# Out:
# 123
