# %% [markdown]
# ### DataTypes

# %%
## Integer
age=35
type(age)
# Out:
# int

# %%
## floating point
height=5.9
type(height)
# Out:
# float

# %%
## string
name="Amit Mungare"
type(name)
# Out:
# str

# %%
## Boolean
is_student=True
type(is_student)
bool()
# Out:
# False

# %%
## common errors

result = "hello"+5
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 ## common errors
#       2
# ----> 3 result = "hello"+5
#       4 print(result)
#
# TypeError: can only concatenate str (not "int") to str
